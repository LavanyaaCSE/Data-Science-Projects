# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
url="C:/Users/chefa/Downloads/oasis/car data.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df = df.drop(columns=['Car_Name'])

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
df.shape
# Out:
# (301, 8)

# %%
df_nan = df.isna()
print(df_nan)
# Out:
#       Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 0    False          False          False       False      False         False
# 1    False          False          False       False      False         False
# 2    False          False          False       False      False         False
# 3    False          False          False       False      False         False
# 4    False          False          False       False      False         False
# ..     ...            ...            ...         ...        ...           ...
# 296  False          False          False       False      False         False
# 297  False          False          False       False      False         False
# 298  False          False          False       False      False         False
# 299  False          False          False       False      False         False
# 300  False          False          False       False      False         False
#
#      Transmission  Owner
# ...

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
sns.pairplot(df, hue='Fuel_Type')

# %%
sns.pairplot(df, hue='Year')

# %%
sns.pairplot(df, hue='Transmission')

# %%
sns.pairplot(df, hue='Driven_kms')

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
df1 = df[['Year','Driven_kms','Fuel_Type','Selling_type','Transmission','Owner','Present_Price','Selling_Price']]

# %%
df1.head()
# Out:
#    Year  Driven_kms Fuel_Type Selling_type Transmission  Owner  Present_Price  \
# 0  2014       27000    Petrol       Dealer       Manual      0           5.59
# 1  2013       43000    Diesel       Dealer       Manual      0           9.54
# 2  2017        6900    Petrol       Dealer       Manual      0           9.85
# 3  2011        5200    Petrol       Dealer       Manual      0           4.15
# 4  2014       42450    Diesel       Dealer       Manual      0           6.87
#
#    Selling_Price
# 0           3.35
# 1           4.75
# 2           7.25
# 3           2.85
# 4           4.60

# %%
df2 = pd.get_dummies(df1['Fuel_Type'], dtype=int)

# %%
df2.head()
# Out:
#    CNG  Diesel  Petrol
# 0    0       0       1
# 1    0       1       0
# 2    0       0       1
# 3    0       0       1
# 4    0       1       0

# %%
df2 = pd.concat([df1,df2],axis=1)

# %%
df2.head()
# Out:
#    Year  Driven_kms Fuel_Type Selling_type Transmission  Owner  Present_Price  \
# 0  2014       27000    Petrol       Dealer       Manual      0           5.59
# 1  2013       43000    Diesel       Dealer       Manual      0           9.54
# 2  2017        6900    Petrol       Dealer       Manual      0           9.85
# 3  2011        5200    Petrol       Dealer       Manual      0           4.15
# 4  2014       42450    Diesel       Dealer       Manual      0           6.87
#
#    Selling_Price  CNG  Diesel  Petrol
# 0           3.35    0       0       1
# 1           4.75    0       1       0
# 2           7.25    0       0       1
# 3           2.85    0       0       1
# 4           4.60    0       1       0

# %%
df2.drop(columns=['Fuel_Type'])
# Out:
#      Year  Driven_kms Selling_type Transmission  Owner  Present_Price  \
# 0    2014       27000       Dealer       Manual      0           5.59
# 1    2013       43000       Dealer       Manual      0           9.54
# 2    2017        6900       Dealer       Manual      0           9.85
# 3    2011        5200       Dealer       Manual      0           4.15
# 4    2014       42450       Dealer       Manual      0           6.87
# ..    ...         ...          ...          ...    ...            ...
# 296  2016       33988       Dealer       Manual      0          11.60
# 297  2015       60000       Dealer       Manual      0           5.90
# 298  2009       87934       Dealer       Manual      0          11.00
# 299  2017        9000       Dealer       Manual      0          12.50
# 300  2016        5464       Dealer       Manual      0           5.90
#
#      Selling_Price  CNG  Diesel  Petrol
# 0             3.35    0       0       1
# 1             4.75    0       1       0
# ...

# %%
df2 = df2[['Year','Driven_kms','Selling_type','Transmission','Owner','CNG','Diesel','Petrol','Present_Price','Selling_Price']]

# %%
df2.head()
# Out:
#    Year  Driven_kms Selling_type Transmission  Owner  CNG  Diesel  Petrol  \
# 0  2014       27000       Dealer       Manual      0    0       0       1
# 1  2013       43000       Dealer       Manual      0    0       1       0
# 2  2017        6900       Dealer       Manual      0    0       0       1
# 3  2011        5200       Dealer       Manual      0    0       0       1
# 4  2014       42450       Dealer       Manual      0    0       1       0
#
#    Present_Price  Selling_Price
# 0           5.59           3.35
# 1           9.54           4.75
# 2           9.85           7.25
# 3           4.15           2.85
# 4           6.87           4.60

# %%
df3 = pd.get_dummies(df2['Selling_type'],dtype=int)

# %%
df3.head()
# Out:
#    Dealer  Individual
# 0       1           0
# 1       1           0
# 2       1           0
# 3       1           0
# 4       1           0

# %%
df3 = pd.concat([df2,df3],axis=1)

# %%
df3.head()
# Out:
#    Year  Driven_kms Selling_type Transmission  Owner  CNG  Diesel  Petrol  \
# 0  2014       27000       Dealer       Manual      0    0       0       1
# 1  2013       43000       Dealer       Manual      0    0       1       0
# 2  2017        6900       Dealer       Manual      0    0       0       1
# 3  2011        5200       Dealer       Manual      0    0       0       1
# 4  2014       42450       Dealer       Manual      0    0       1       0
#
#    Present_Price  Selling_Price  Dealer  Individual
# 0           5.59           3.35       1           0
# 1           9.54           4.75       1           0
# 2           9.85           7.25       1           0
# 3           4.15           2.85       1           0
# 4           6.87           4.60       1           0

# %%
df3.drop(columns='Selling_type')
# Out:
#      Year  Driven_kms Transmission  Owner  CNG  Diesel  Petrol  Present_Price  \
# 0    2014       27000       Manual      0    0       0       1           5.59
# 1    2013       43000       Manual      0    0       1       0           9.54
# 2    2017        6900       Manual      0    0       0       1           9.85
# 3    2011        5200       Manual      0    0       0       1           4.15
# 4    2014       42450       Manual      0    0       1       0           6.87
# ..    ...         ...          ...    ...  ...     ...     ...            ...
# 296  2016       33988       Manual      0    0       1       0          11.60
# 297  2015       60000       Manual      0    0       0       1           5.90
# 298  2009       87934       Manual      0    0       0       1          11.00
# 299  2017        9000       Manual      0    0       1       0          12.50
# 300  2016        5464       Manual      0    0       0       1           5.90
#
# ...

# %%
df3[['Year','Driven_kms','Transmission','Owner','CNG','Diesel','Petrol','Dealer','Individual','Present_Price','Selling_Price']]
# Out:
#      Year  Driven_kms Transmission  Owner  CNG  Diesel  Petrol  Dealer  \
# 0    2014       27000       Manual      0    0       0       1       1
# 1    2013       43000       Manual      0    0       1       0       1
# 2    2017        6900       Manual      0    0       0       1       1
# 3    2011        5200       Manual      0    0       0       1       1
# 4    2014       42450       Manual      0    0       1       0       1
# ..    ...         ...          ...    ...  ...     ...     ...     ...
# 296  2016       33988       Manual      0    0       1       0       1
# 297  2015       60000       Manual      0    0       0       1       1
# 298  2009       87934       Manual      0    0       0       1       1
# 299  2017        9000       Manual      0    0       1       0       1
# 300  2016        5464       Manual      0    0       0       1       1
#
#      Individual  Present_Price  Selling_Price
# 0             0           5.59           3.35
# ...

# %%
df4 = pd.get_dummies(df3['Transmission'],dtype=int)

# %%
df4.head()
# Out:
#    Automatic  Manual
# 0          0       1
# 1          0       1
# 2          0       1
# 3          0       1
# 4          0       1

# %%
df4 = pd.concat([df3,df4],axis=1)

# %%
df4.head()
# Out:
#    Year  Driven_kms Selling_type Transmission  Owner  CNG  Diesel  Petrol  \
# 0  2014       27000       Dealer       Manual      0    0       0       1
# 1  2013       43000       Dealer       Manual      0    0       1       0
# 2  2017        6900       Dealer       Manual      0    0       0       1
# 3  2011        5200       Dealer       Manual      0    0       0       1
# 4  2014       42450       Dealer       Manual      0    0       1       0
#
#    Present_Price  Selling_Price  Dealer  Individual  Automatic  Manual
# 0           5.59           3.35       1           0          0       1
# 1           9.54           4.75       1           0          0       1
# 2           9.85           7.25       1           0          0       1
# 3           4.15           2.85       1           0          0       1
# 4           6.87           4.60       1           0          0       1

# %%
df5 = df4.drop(columns=['Selling_type'])

# %%
df5 = df5.drop(columns=['Transmission'])

# %%
df5.head()
# Out:
#    Year  Driven_kms  Owner  CNG  Diesel  Petrol  Present_Price  Selling_Price  \
# 0  2014       27000      0    0       0       1           5.59           3.35
# 1  2013       43000      0    0       1       0           9.54           4.75
# 2  2017        6900      0    0       0       1           9.85           7.25
# 3  2011        5200      0    0       0       1           4.15           2.85
# 4  2014       42450      0    0       1       0           6.87           4.60
#
#    Dealer  Individual  Automatic  Manual
# 0       1           0          0       1
# 1       1           0          0       1
# 2       1           0          0       1
# 3       1           0          0       1
# 4       1           0          0       1

# %%
df5 = df5[['Year','Driven_kms','Owner','CNG','Diesel','Petrol','Dealer','Individual','Automatic','Manual','Present_Price','Selling_Price']]

# %%
df5.head()
# Out:
#    Year  Driven_kms  Owner  CNG  Diesel  Petrol  Dealer  Individual  \
# 0  2014       27000      0    0       0       1       1           0
# 1  2013       43000      0    0       1       0       1           0
# 2  2017        6900      0    0       0       1       1           0
# 3  2011        5200      0    0       0       1       1           0
# 4  2014       42450      0    0       1       0       1           0
#
#    Automatic  Manual  Present_Price  Selling_Price
# 0          0       1           5.59           3.35
# 1          0       1           9.54           4.75
# 2          0       1           9.85           7.25
# 3          0       1           4.15           2.85
# 4          0       1           6.87           4.60

# %%
sns.pairplot(df5,hue='Owner')

# %%
sns.pairplot(df5,hue='Year')

# %%
df5.shape
# Out:
# (301, 12)

# %%
df5.describe()
# Out:
#               Year     Driven_kms       Owner         CNG      Diesel  \
# count   301.000000     301.000000  301.000000  301.000000  301.000000
# mean   2013.627907   36947.205980    0.043189    0.006645    0.199336
# std       2.891554   38886.883882    0.247915    0.081378    0.400166
# min    2003.000000     500.000000    0.000000    0.000000    0.000000
# 25%    2012.000000   15000.000000    0.000000    0.000000    0.000000
# 50%    2014.000000   32000.000000    0.000000    0.000000    0.000000
# 75%    2016.000000   48767.000000    0.000000    0.000000    0.000000
# max    2018.000000  500000.000000    3.000000    1.000000    1.000000
#
#            Petrol      Dealer  Individual   Automatic      Manual  \
# count  301.000000  301.000000  301.000000  301.000000  301.000000
# mean     0.794020    0.647841    0.352159    0.132890    0.867110
# std      0.405089    0.478439    0.478439    0.340021    0.340021
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
sns.boxplot(df5['Dealer'])
# Out:
# <Axes: ylabel='Dealer'>

# %%
sns.boxplot(df5['Individual'])
# Out:
# <Axes: ylabel='Individual'>

# %%
sns.boxplot(df5['Selling_Price'])
# Out:
# <Axes: ylabel='Selling_Price'>

# %%
df5.head()
# Out:
#    Year  Driven_kms  Owner  CNG  Diesel  Petrol  Dealer  Individual  \
# 0  2014       27000      0    0       0       1       1           0
# 1  2013       43000      0    0       1       0       1           0
# 2  2017        6900      0    0       0       1       1           0
# 3  2011        5200      0    0       0       1       1           0
# 4  2014       42450      0    0       1       0       1           0
#
#    Automatic  Manual  Present_Price  Selling_Price
# 0          0       1           5.59           3.35
# 1          0       1           9.54           4.75
# 2          0       1           9.85           7.25
# 3          0       1           4.15           2.85
# 4          0       1           6.87           4.60

# %%
data=df5.values
x=data[:,0:11]
y=data[:,11]

# %%
x
# Out:
# array([[2.0140e+03, 2.7000e+04, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         5.5900e+00],
#        [2.0130e+03, 4.3000e+04, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         9.5400e+00],
#        [2.0170e+03, 6.9000e+03, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         9.8500e+00],
#        ...,
#        [2.0090e+03, 8.7934e+04, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         1.1000e+01],
#        [2.0170e+03, 9.0000e+03, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         1.2500e+01],
#        [2.0160e+03, 5.4640e+03, 0.0000e+00, ..., 0.0000e+00, 1.0000e+00,
#         5.9000e+00]])

# %%
y
# Out:
# array([ 3.35,  4.75,  7.25,  2.85,  4.6 ,  9.25,  6.75,  6.5 ,  8.75,
#         7.45,  2.85,  6.85,  7.5 ,  6.1 ,  2.25,  7.75,  7.25,  7.75,
#         3.25,  2.65,  2.85,  4.9 ,  4.4 ,  2.5 ,  2.9 ,  3.  ,  4.15,
#         6.  ,  1.95,  7.45,  3.1 ,  2.35,  4.95,  6.  ,  5.5 ,  2.95,
#         4.65,  0.35,  3.  ,  2.25,  5.85,  2.55,  1.95,  5.5 ,  1.25,
#         7.5 ,  2.65,  1.05,  5.8 ,  7.75, 14.9 , 23.  , 18.  , 16.  ,
#         2.75,  3.6 ,  4.5 ,  4.75,  4.1 , 19.99,  6.95,  4.5 , 18.75,
#        23.5 , 33.  ,  4.75, 19.75,  9.25,  4.35, 14.25,  3.95,  4.5 ,
#         7.45,  2.65,  4.9 ,  3.95,  5.5 ,  1.5 ,  5.25, 14.5 , 14.73,
#         4.75, 23.  , 12.5 ,  3.49,  2.5 , 35.  ,  5.9 ,  3.45,  4.75,
#         3.8 , 11.25,  3.51, 23.  ,  4.  ,  5.85, 20.75, 17.  ,  7.05,
#         9.65,  1.75,  1.7 ,  1.65,  1.45,  1.35,  1.35,  1.35,  1.25,
#         1.2 ,  1.2 ,  1.2 ,  1.15,  1.15,  1.15,  1.15,  1.11,  1.1 ,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(input_scaled2,y,test_size=0.2)

# %%
x_train
# Out:
#          Year  Driven_kms  Owner  CNG  Diesel  Petrol  Dealer  Individual  \
# 194 -1.949567    0.336220      0    0       0       1       0           1
# 73  -0.910335    0.155911      0    0       0       1       1           0
# 75   0.475308   -0.024399      0    0       0       1       1           0
# 264  0.475308    0.079305      0    0       0       1       1           0
# 1   -0.217514    0.155911      0    0       1       0       1           0
# ..        ...         ...    ...  ...     ...     ...     ...         ...
# 291  0.475308   -0.142192      0    0       0       1       1           0
# 162 -0.563924   -0.578205      0    0       0       1       0           1
# 233 -0.217514    0.413495      0    0       1       0       1           0
# 66   1.168129   -0.668359      0    0       0       1       1           0
# 2    1.168129   -0.773969      0    0       0       1       1           0
#
#      Automatic  Manual
# 194          0       1
# 73           0       1
# ...

# %%
y_train
# Out:
# array([ 0.2 ,  2.65,  3.95,  4.  ,  4.75, 35.  ,  0.25,  4.65,  5.3 ,
#         4.15,  1.05,  7.75,  0.9 ,  2.9 ,  4.  ,  6.25,  5.5 , 19.99,
#         1.05,  6.1 ,  0.38,  3.  ,  0.48,  1.25,  0.48,  4.75,  0.6 ,
#         8.4 ,  2.75,  4.1 ,  0.4 ,  1.1 ,  4.75, 10.25,  7.75,  3.45,
#        12.5 ,  8.25,  4.6 ,  5.3 ,  6.75,  3.95,  7.45,  4.95, 11.25,
#         1.11,  3.51,  0.25,  1.65, 20.75,  4.  ,  3.1 ,  3.5 ,  4.5 ,
#         2.85,  1.15,  6.6 ,  8.25,  3.1 ,  0.15,  0.6 ,  0.9 ,  2.25,
#         5.25,  3.1 ,  2.55,  3.65,  0.1 ,  1.1 ,  2.55,  0.35,  6.5 ,
#         4.1 , 18.  ,  4.5 ,  1.2 ,  1.05,  1.95,  0.12,  5.25,  0.25,
#         2.7 ,  0.2 ,  5.75,  7.45,  7.2 ,  4.5 ,  5.8 ,  4.75,  0.75,
#         1.25,  3.75,  8.55,  0.52,  0.48,  4.9 ,  0.38,  3.25,  0.75,
#        11.75,  2.95,  4.4 ,  0.2 ,  0.6 ,  9.65,  5.5 ,  5.9 ,  6.25,
#        14.5 ,  5.85, 11.25,  1.15,  0.35,  6.  ,  7.5 ,  5.75,  0.42,
# ...

# %%
x_test
# Out:
#          Year  Driven_kms  Owner  CNG  Diesel  Petrol  Dealer  Individual  \
# 245 -0.563924    0.877147      0    0       1       0       1           0
# 226  0.475308   -0.316036      0    0       0       1       1           0
# 180 -0.563924    0.593804      0    0       0       1       0           1
# 209  0.475308   -0.407555      0    0       1       0       1           0
# 182 -0.217514   -0.178949      0    0       0       1       0           1
# ..        ...         ...    ...  ...     ...     ...     ...         ...
# 21   1.168129   -0.889882      0    0       0       1       1           0
# 143  0.821718   -0.307741      0    0       0       1       0           1
# 108  0.821718   -0.488050      0    0       0       1       0           1
# 159  1.168129   -0.848668      0    0       0       1       0           1
# 106  0.128897   -0.526688      1    0       0       1       0           1
#
#      Automatic  Manual
# 245          0       1
# 226          0       1
# ...

# %%
y_test
# Out:
# array([ 5.2 ,  5.25,  0.3 ,  4.85,  0.3 ,  0.8 , 11.5 ,  8.35,  0.35,
#         9.15,  0.4 ,  1.7 ,  6.  ,  1.45, 23.  ,  0.17,  1.  , 14.25,
#         1.05,  5.25,  0.45,  3.  ,  0.6 ,  0.6 ,  7.4 ,  3.6 ,  5.95,
#         0.45,  3.  ,  3.35,  4.95,  2.5 ,  3.75,  6.85, 14.73,  9.1 ,
#         0.65,  1.2 ,  6.4 ,  0.45,  0.5 ,  4.8 ,  4.8 ,  0.42,  5.35,
#         3.8 ,  2.25, 33.  ,  6.  ,  0.4 ,  9.25,  7.5 ,  0.16, 12.9 ,
#        18.75,  9.5 ,  4.9 ,  0.6 ,  1.2 ,  0.45,  1.35])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred_rf = rf.predict(x_test)
r_squared = r2_score(y_test,y_pred_rf)
rmse = np.sqrt(mean_squared_error(y_test,y_pred_rf))
print("R_squared :",r_squared)
print("RMSE :",rmse)
# Out:
# R_squared : 0.9302473814833344
# RMSE : 1.5812104402060367

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

rf.fit(x_train,y_train)

y_pred_rf = rf.predict(x_test)

r_squared = r2_score(y_test,y_pred_rf)
rmse = np.sqrt(mean_squared_error(y_test,y_pred_rf))
print("R_squared :",r_squared)
print("RMSE :",rmse)
# Out:
# R_squared : 0.7895149766177263
# RMSE : 2.7467555791630334

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbt = GradientBoostingRegressor()

gbt.fit(x_train,y_train)

y_pred_gbt = gbt.predict(x_test)

r_squared = r2_score(y_test,y_pred_gbt)
rmse = np.sqrt(mean_squared_error(y_test,y_pred_gbt))
print("R_squared :",r_squared)
print("RMSE :",rmse)
# Out:
# R_squared : 0.8039414597925737
# RMSE : 2.650954646223852

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, y_pred_gbt))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_gbt))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_gbt)))
# Out:
# MAE: 1.44751352497429
# MSE: 7.027560536335828
# RMSE: 2.650954646223852

# %%
df5.head()
# Out:
#    Year  Driven_kms  Owner  CNG  Diesel  Petrol  Dealer  Individual  \
# 0  2014       27000      0    0       0       1       1           0
# 1  2013       43000      0    0       1       0       1           0
# 2  2017        6900      0    0       0       1       1           0
# 3  2011        5200      0    0       0       1       1           0
# 4  2014       42450      0    0       1       0       1           0
#
#    Automatic  Manual  Present_Price  Selling_Price
# 0          0       1           5.59           3.35
# 1          0       1           9.54           4.75
# 2          0       1           9.85           7.25
# 3          0       1           4.15           2.85
# 4          0       1           6.87           4.60

# %%
x_new = np.array([[2014,27000,0,0,0,1,1,0,0,1]])
prediction = gbt.predict(x_new)
print("Used car price:{}".format(prediction))
# Out:
# Used car price:[3.91602829]
